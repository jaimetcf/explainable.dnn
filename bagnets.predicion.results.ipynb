# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##########################################################################################
# UTILITIES CODE. RUN THIS CELL BEFORE EXECUTING ANYTHING ELSE IN THIS NOTEBOOK
##########################################################################################

# This ensures the same model, data and parâmeters produce repeatable results ############
import numpy as np
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.random.set_seed(3)
##########################################################################################

import os
import matplotlib.pyplot as plt
import cv2 as cv


# IMAGE PROCESSING FUNCTIONS #############################################################

# Loads images from images_path folder and splits in train and test datasets 
def loadImages(images_path, batch_size, imgHeight, imgWidth):
    import tensorflow as tf

    train_set = tf.keras.preprocessing.image_dataset_from_directory(
        directory = images_path,
        labels="inferred",
        label_mode="categorical",
        class_names=None,
        batch_size = batch_size,
        color_mode = "rgb",
        image_size = (imgHeight, imgWidth),
        interpolation = "bilinear",
        seed = 700,
        shuffle = True,
        validation_split = 0.125,
        subset = 'training'
    )#.map(lambda x, y: (x/255.0, y) )

    test_set = tf.keras.preprocessing.image_dataset_from_directory(
        directory = images_path,
        labels="inferred",
        label_mode="categorical",
        class_names=None,
        batch_size = batch_size,
        color_mode = "rgb",
        image_size = (imgHeight, imgWidth),
        interpolation = "bilinear",
        seed = 700,
        shuffle = True,
        validation_split = 0.125,
        subset = 'validation'
    )#.map(lambda x, y: (x/255.0, y) )

    return( train_set, test_set)

def datasetToTensors(dataset):
    images = []
    labels = []
    for batch in dataset:
        (imagesBatch, labelsBatch) = batch
        images.append( imagesBatch )
        labels.append( labelsBatch )
    return( np.concatenate(images, axis=0 ), np.concatenate(labels, axis=0 ) )


# HEATMAP EXTRACTION FUNCTIONS ###########################################################
def predictHeatmaps(model, image, heatmapHeight, heatmapWidth):
    # Extracts an intermediate model that outputs heatmap logits
    heatmapsModel = getHeatmapsModel( 
        model, 
        1024, 1280 ) # These numbers are model summary Dense numbers 

    logitsList = heatmapsModel.predict(image)
    heatmaps = np.concatenate(logitsList)
    class0Heatmap = heatmaps[:,0].reshape(heatmapHeight,heatmapWidth)
    class1Heatmap   = heatmaps[:,1].reshape(heatmapHeight,heatmapWidth)
    return ( class0Heatmap, class1Heatmap )

def getHeatmapsModel(model, start, end):
    from keras import models
    return models.Model( inputs=model.input, outputs=getLogits(model,start, end) )

def getLogits(model, start, end):
    from keras import layers
    from keras import models
    return [ 
        model.get_layer('dense').output if i==0 
        else model.get_layer('dense_' + str(i)).output 
        for i in range(start,end)
    ]


# DISPLAY DATA FUNCTIONS #################################################################
def displayPredictionResults( model, 
                              images, labels, index, 
                              ratesColor, chartSize 
):
    print('IMAGE =>', index)
    print( 'Truth -> Dandelion' if labels[index][0] == 1 else 'Truth -> Sunflower' )  
    
    classProbabilitites, dandelionHmap, sunflowerHmap = getPredictions(
        model, images[index]  )

    displayPredictions( images[index], 
                        classProbabilitites, dandelionHmap, sunflowerHmap, 
                        ratesColor, chartSize   )
    print(' ')

def getPredictions(model, image):
    # model requires a batch of images as input, rescaled into range (0 - 1)
    imageBatch = np.reshape( image, (1, IM_HEIGHT, IM_WIDTH, 3) ) / 255.0

    # Predict class: Dandelion or Sunflower
    classProbabilitites = model.predict(imageBatch)
    
    # Gets heatmap predictions from model
    ( dandelionHmap, sunflowerHmap ) = predictHeatmaps(
            model, imageBatch, 
            int(IM_HEIGHT/PATCH_HEIGHT), int(IM_WIDTH / PATCH_WIDTH)  )

    return classProbabilitites, dandelionHmap, sunflowerHmap

def displayPredictions(
    image, 
    classProbabilitites, dandelionHmap, sunflowerHmap, 
    ratesColor, chartSize
):
    print(
        'Inference:  Dandelion=>', classProbabilitites[0,0], 
        '   Sunflower=>', classProbabilitites[0,1]  )
    
    # Rescales the raw heatmap into the 0 - 255 range
    rescaledHmap = rescaleHeatmap( dandelionHmap - sunflowerHmap )     
    
    # creates a (IM_HEIGHT, IM WIDTH, 3) image from the heatmap
    heatmapImage = heatmapToImage(rescaledHmap, IM_HEIGHT, IM_WIDTH, 
                                  PATCH_HEIGHT, PATCH_WIDTH)
    
    # Writes heatmap rates on the image
    imageBlended = blendImageAndRates( image, 
                                       heatmapToRange(rescaledHmap, -9, 9 ), 
                                       IM_HEIGHT, IM_WIDTH, PATCH_HEIGHT, 
                                       PATCH_WIDTH, ratesColor )
    # displays result image
    displayHeatmap( np.array( imageBlended, dtype=int ), heatmapImage, chartSize )

# Rescales the raw heatmap outputed by Dense layers into the 0 - 255 range, 
# with zero being mapped to 128
def rescaleHeatmap(heatmap):
    from sklearn.preprocessing import MinMaxScaler
    hmapMax = np.max(heatmap)  
    hmapMin = np.abs(np.min(heatmap))
    endOfScale = hmapMax if hmapMax > hmapMin else hmapMin
    scaler = 127.0 / endOfScale
    hmapScaled = np.array( (heatmap * scaler) + 127.0, dtype=int )
    hmapScaled[hmapScaled < 0] = 0
    return hmapScaled

# creates a (imgHeight, imgWidth, 3) rgb image from a heatmap (nRows, nCols)
def heatmapToImage(heatmap, imgHeight, imgWidth, patchHeight, patchWidth):
    image = np.zeros( (imgHeight, imgWidth), np.uint8)
    hmapHeight, hmapWidth = heatmap.shape
    nRows = int(imgHeight / patchHeight)
    nCols = int(imgWidth / patchWidth)
    for row in range(nRows):
        for col in range(nCols):
            image[(row*patchHeight):((row+1)*patchHeight), 
                  (col*patchWidth):((col+1)*patchWidth)] = int(heatmap[row,col])

    return image

# Converts heatmap values from the (0-255) range into a specified integer range
# start and end must be integers and (end > start) must hold True 
def heatmapToRange(heatmap, start, end):
    nRows, nCols = heatmap.shape
    rates = np.zeros((nRows,nCols))
    for row in range(nRows):
        for col in range(nCols):
            rates[row,col] = start + round((end-start) * heatmap[row,col] / 255.0)
    
    return rates

# Plots heatmap rates on the image
def blendImageAndRates( 
    imageRgb, rates, imgHeight, imgWidth, patchHeight, patchWidth, ratesColor
):
    # copy() needed because, otherwise, opencv would overwrite original tensor image
    image = imageRgb.copy()
    imgBgr = rgbToBgr(image)  # opencv assumes a bgr image, instead of rgb

    nRows = int(imgHeight / patchHeight)
    nCols = int(imgWidth / patchWidth)
    # Plots grid lines
    for row in range(1,nRows):
        cv.line( imgBgr, 
                ( 0,patchHeight*row ), ( imgWidth,patchHeight*row ), ratesColor, 1)
    for col in range(1,nCols):
        cv.line( imgBgr, 
                ( patchWidth*col,0 ), ( patchWidth*col,imgHeight ), ratesColor, 1)

    # Plots rates on image
    for row in range(0,nRows):
        for col in range(0,nCols):
            rate = int(rates[row,col])
            if( rate < 0 ):
                cv.putText( imgBgr, str(rate), 
                            ( patchWidth*col + 3, patchHeight*(row+1) - 6 ), 
                            cv.FONT_HERSHEY_SIMPLEX, 0.2, ratesColor, 1, cv.LINE_AA )
            else:
                cv.putText( imgBgr, str(rate), 
                            ( patchWidth*col + 7, patchHeight*(row+1) - 6 ), 
                            cv.FONT_HERSHEY_SIMPLEX, 0.2, ratesColor, 1, cv.LINE_AA )
    
    return bgrToRgb(imgBgr)

# Replace opencv functions here. These don't overwrite original images
# and accept dtypes float or int
def rgbToBgr(imgRgb):
    imgBgr = imgRgb.copy()
    imgBgr[:,:,0] = imgRgb[:,:,2] 
    imgBgr[:,:,1] = imgRgb[:,:,1] 
    imgBgr[:,:,2] = imgRgb[:,:,0]
    return imgBgr

def bgrToRgb(imgBgr):
    imgRgb = imgBgr.copy()
    imgRgb[:,:,0] = imgBgr[:,:,2] 
    imgRgb[:,:,1] = imgBgr[:,:,1] 
    imgRgb[:,:,2] = imgBgr[:,:,0]
    return imgRgb

# Displays the image and a heatmap
def displayHeatmap( image, heatmap, chart_size):
    import matplotlib.pyplot as plt
    f, ax = plt.subplots(figsize=(2*chart_size, chart_size))
    plt.subplot(1,2,1), plt.imshow(image, vmin=0, vmax=1.0)
    plt.title('ORIGINAL IMAGE WITH CLASS EVIDENCE'), plt.xticks([]), plt.yticks([])
    plt.xlabel('Positive numbers indicate Dandelion, negative indicate Sunflower')
    plt.subplot(1,2,2),plt.imshow(heatmap, cmap='viridis', vmin=0, vmax=255)
    plt.title('CLASS EVIDENCE HEATMAP'), plt.xticks([]), plt.yticks([])
    plt.xlabel('Yellow and Green indicate Dandelion, Blue and Purple indicate Sunflower')
    plt.show()

# %%
IM_HEIGHT = 256
IM_WIDTH = 256
PATCH_HEIGHT = 16
PATCH_WIDTH = 16

BATCH_SIZE = 128

images_path = "/content/drive/My Drive/projects/ds_projects/explainable.dnn/images"

( train_set, test_set ) = loadImages(images_path, BATCH_SIZE, IM_HEIGHT, IM_WIDTH)
X_test, y_test = datasetToTensors(test_set)

print(X_test.shape)
print(y_test.shape)
# Out:
# Found 2048 files belonging to 2 classes.
# Using 1792 files for training.
# Found 2048 files belonging to 2 classes.
# Using 256 files for validation.
# (256, 256, 256, 3)
# (256, 2)

# %%
from keras.models import load_model

models_path = "/content/drive/My Drive/projects/ds_projects/explainable.dnn/models"
model_name = "/bagnets.model"

model = load_model(models_path + model_name, compile = True)
model.summary()
# Out:
# Streaming output truncated to the last 5000 lines.
#  tf.__operators__.getitem_1152   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1153   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1154   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1155   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1156   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1157   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1158   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1159   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1160   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1161   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1162   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1163   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1164   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1165   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1166   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1167   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1168   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1169   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1170   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1171   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1172   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1173   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1174   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1175   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1176   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1177   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1178   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1179   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1180   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1181   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1182   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1183   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1184   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1185   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1186   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1187   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1188   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1189   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1190   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1191   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1192   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1193   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1194   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1195   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1196   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1197   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1198   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1199   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1200   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1201   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1202   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1203   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1204   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1205   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1206   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1207   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1208   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1209   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1210   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1211   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1212   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1213   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1214   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1215   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1216   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1217   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1218   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1219   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1220   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1221   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1222   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1223   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1224   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1225   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1226   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1227   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1228   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1229   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1230   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1231   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1232   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1233   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1234   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1235   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1236   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1237   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1238   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1239   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1240   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1241   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1242   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1243   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1244   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1245   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1246   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1247   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1248   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1249   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1250   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1251   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1252   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1253   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1254   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1255   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1256   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1257   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1258   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1259   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1260   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1261   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1262   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1263   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1264   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1265   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1266   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1267   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1268   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1269   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1270   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1271   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1272   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1273   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1274   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1275   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1276   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1277   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1278   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  tf.__operators__.getitem_1279   (None, 16, 16, 3)   0           ['input_5[0][0]']
#  (SlicingOpLambda)
#
#  batch_normalization_1024 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1024[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1025 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1025[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1026 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1026[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1027 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1027[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1028 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1028[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1029 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1029[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1030 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1030[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1031 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1031[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1032 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1032[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1033 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1033[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1034 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1034[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1035 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1035[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1036 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1036[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1037 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1037[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1038 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1038[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1039 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1039[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1040 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1040[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1041 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1041[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1042 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1042[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1043 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1043[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1044 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1044[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1045 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1045[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1046 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1046[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1047 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1047[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1048 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1048[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1049 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1049[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1050 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1050[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1051 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1051[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1052 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1052[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1053 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1053[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1054 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1054[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1055 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1055[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1056 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1056[0
#  hNormalization)                                                 ][0]']
#
#  batch_normalization_1057 (Batc  (None, 16, 16, 3)   12          ['tf.__operators__.getitem_1057[0
# ...
#                                                                   'dense_1125[0][0]',
#                                                                   'dense_1126[0][0]',
#                                                                   'dense_1127[0][0]',
#                                                                   'dense_1128[0][0]',
#                                                                   'dense_1129[0][0]',
#                                                                   'dense_1130[0][0]',
#                                                                   'dense_1131[0][0]',
#                                                                   'dense_1132[0][0]',
#                                                                   'dense_1133[0][0]',
#                                                                   'dense_1134[0][0]',
#                                                                   'dense_1135[0][0]',
#                                                                   'dense_1136[0][0]',
#                                                                   'dense_1137[0][0]',
#                                                                   'dense_1138[0][0]',
#                                                                   'dense_1139[0][0]',
#                                                                   'dense_1140[0][0]',
#                                                                   'dense_1141[0][0]',
#                                                                   'dense_1142[0][0]',
#                                                                   'dense_1143[0][0]',
#                                                                   'dense_1144[0][0]',
#                                                                   'dense_1145[0][0]',
#                                                                   'dense_1146[0][0]',
#                                                                   'dense_1147[0][0]',
#                                                                   'dense_1148[0][0]',
#                                                                   'dense_1149[0][0]',
#                                                                   'dense_1150[0][0]',
#                                                                   'dense_1151[0][0]',
#                                                                   'dense_1152[0][0]',
#                                                                   'dense_1153[0][0]',
#                                                                   'dense_1154[0][0]',
#                                                                   'dense_1155[0][0]',
#                                                                   'dense_1156[0][0]',
#                                                                   'dense_1157[0][0]',
#                                                                   'dense_1158[0][0]',
#                                                                   'dense_1159[0][0]',
#                                                                   'dense_1160[0][0]',
#                                                                   'dense_1161[0][0]',
#                                                                   'dense_1162[0][0]',
#                                                                   'dense_1163[0][0]',
#                                                                   'dense_1164[0][0]',
#                                                                   'dense_1165[0][0]',
#                                                                   'dense_1166[0][0]',
#                                                                   'dense_1167[0][0]',
#                                                                   'dense_1168[0][0]',
#                                                                   'dense_1169[0][0]',
#                                                                   'dense_1170[0][0]',
#                                                                   'dense_1171[0][0]',
#                                                                   'dense_1172[0][0]',
#                                                                   'dense_1173[0][0]',
#                                                                   'dense_1174[0][0]',
#                                                                   'dense_1175[0][0]',
#                                                                   'dense_1176[0][0]',
#                                                                   'dense_1177[0][0]',
#                                                                   'dense_1178[0][0]',
#                                                                   'dense_1179[0][0]',
#                                                                   'dense_1180[0][0]',
#                                                                   'dense_1181[0][0]',
#                                                                   'dense_1182[0][0]',
#                                                                   'dense_1183[0][0]',
#                                                                   'dense_1184[0][0]',
#                                                                   'dense_1185[0][0]',
#                                                                   'dense_1186[0][0]',
#                                                                   'dense_1187[0][0]',
#                                                                   'dense_1188[0][0]',
#                                                                   'dense_1189[0][0]',
#                                                                   'dense_1190[0][0]',
#                                                                   'dense_1191[0][0]',
#                                                                   'dense_1192[0][0]',
#                                                                   'dense_1193[0][0]',
#                                                                   'dense_1194[0][0]',
#                                                                   'dense_1195[0][0]',
#                                                                   'dense_1196[0][0]',
#                                                                   'dense_1197[0][0]',
#                                                                   'dense_1198[0][0]',
#                                                                   'dense_1199[0][0]',
#                                                                   'dense_1200[0][0]',
#                                                                   'dense_1201[0][0]',
#                                                                   'dense_1202[0][0]',
#                                                                   'dense_1203[0][0]',
#                                                                   'dense_1204[0][0]',
#                                                                   'dense_1205[0][0]',
#                                                                   'dense_1206[0][0]',
#                                                                   'dense_1207[0][0]',
#                                                                   'dense_1208[0][0]',
#                                                                   'dense_1209[0][0]',
#                                                                   'dense_1210[0][0]',
#                                                                   'dense_1211[0][0]',
#                                                                   'dense_1212[0][0]',
#                                                                   'dense_1213[0][0]',
#                                                                   'dense_1214[0][0]',
#                                                                   'dense_1215[0][0]',
#                                                                   'dense_1216[0][0]',
#                                                                   'dense_1217[0][0]',
#                                                                   'dense_1218[0][0]',
#                                                                   'dense_1219[0][0]',
#                                                                   'dense_1220[0][0]',
#                                                                   'dense_1221[0][0]',
#                                                                   'dense_1222[0][0]',
#                                                                   'dense_1223[0][0]',
#                                                                   'dense_1224[0][0]',
#                                                                   'dense_1225[0][0]',
#                                                                   'dense_1226[0][0]',
#                                                                   'dense_1227[0][0]',
#                                                                   'dense_1228[0][0]',
#                                                                   'dense_1229[0][0]',
#                                                                   'dense_1230[0][0]',
#                                                                   'dense_1231[0][0]',
#                                                                   'dense_1232[0][0]',
#                                                                   'dense_1233[0][0]',
#                                                                   'dense_1234[0][0]',
#                                                                   'dense_1235[0][0]',
#                                                                   'dense_1236[0][0]',
#                                                                   'dense_1237[0][0]',
#                                                                   'dense_1238[0][0]',
#                                                                   'dense_1239[0][0]',
#                                                                   'dense_1240[0][0]',
#                                                                   'dense_1241[0][0]',
#                                                                   'dense_1242[0][0]',
#                                                                   'dense_1243[0][0]',
#                                                                   'dense_1244[0][0]',
#                                                                   'dense_1245[0][0]',
#                                                                   'dense_1246[0][0]',
#                                                                   'dense_1247[0][0]',
#                                                                   'dense_1248[0][0]',
#                                                                   'dense_1249[0][0]',
#                                                                   'dense_1250[0][0]',
#                                                                   'dense_1251[0][0]',
#                                                                   'dense_1252[0][0]',
#                                                                   'dense_1253[0][0]',
#                                                                   'dense_1254[0][0]',
#                                                                   'dense_1255[0][0]',
#                                                                   'dense_1256[0][0]',
#                                                                   'dense_1257[0][0]',
#                                                                   'dense_1258[0][0]',
#                                                                   'dense_1259[0][0]',
#                                                                   'dense_1260[0][0]',
#                                                                   'dense_1261[0][0]',
#                                                                   'dense_1262[0][0]',
#                                                                   'dense_1263[0][0]',
#                                                                   'dense_1264[0][0]',
#                                                                   'dense_1265[0][0]',
#                                                                   'dense_1266[0][0]',
#                                                                   'dense_1267[0][0]',
#                                                                   'dense_1268[0][0]',
#                                                                   'dense_1269[0][0]',
#                                                                   'dense_1270[0][0]',
#                                                                   'dense_1271[0][0]',
#                                                                   'dense_1272[0][0]',
#                                                                   'dense_1273[0][0]',
#                                                                   'dense_1274[0][0]',
#                                                                   'dense_1275[0][0]',
#                                                                   'dense_1276[0][0]',
#                                                                   'dense_1277[0][0]',
#                                                                   'dense_1278[0][0]',
#                                                                   'dense_1279[0][0]']
#
#  tf.nn.softmax_4 (TFOpLambda)   (None, 2)            0           ['average_4[0][0]']
#
# ==================================================================================================
# Total params: 916,992
# Trainable params: 915,456
# Non-trainable params: 1,536
# __________________________________________________________________________________________________

# %%
# Dandelion samples -> 3, 6, 10, 12, 13, 14, 255
ratesColor = (100,100,100)
displayPredictionResults( model, X_test, y_test, 0, ratesColor, 8 )   # Sunflower
displayPredictionResults( model, X_test, y_test, 9, (8,8,8), 8 )   # Sunflower
displayPredictionResults( model, X_test, y_test, 20, ratesColor, 8 )  # Sunflower

displayPredictionResults( model, X_test, y_test, 3, ratesColor, 8 )   # Dandelion
displayPredictionResults( model, X_test, y_test, 6, ratesColor, 8 )   # Dandelion
displayPredictionResults( model, X_test, y_test, 12, ratesColor, 8 )  # Dandelion
#displayPredictionResults( model, X_test, y_test, 255, ratesColor, 8 ) # Dandelion
# Out:
# Output hidden; open in https://colab.research.google.com to view.
